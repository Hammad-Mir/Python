# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get('http://iustlive.com/Index/examination/onlineexamresults.aspx')

# %%
cse = 'CSE-15-'

cse_list = []

for i in range (1, 130):
    if i < 10:
        cse_list.append(cse + '0' + str(i))
        continue
        
    cse_list.append(cse + str(i))
    
#cse_list

#cse_list.remove('CSE-15-07')

# %%
registration_no = '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[2]/td[2]/input'

semester = ['/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[3]/td[2]/select/option[3]',
            '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[3]/td[2]/select/option[4]',
            '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[3]/td[2]/select/option[5]',
            '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[3]/td[2]/select/option[6]',
            '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[3]/td[2]/select/option[7]',
            '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[3]/td[2]/select/option[8]',
            '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[3]/td[2]/select/option[9]']

get_result = '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[4]/td[2]/input'

name = '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/div/div/table/tbody/tr[3]/td[2]/input'

sgpa = '/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/div/div/table/tbody/tr[5]/td[4]/input'

# %%
for student in cse_list:
    i = 0.00
    driver.find_element_by_xpath(registration_no).send_keys(student)
    
    driver.find_element_by_xpath('/html/body/div[2]/form/div[3]/div/div/div[2]/div[2]/div/div/div/div/div/table[1]/tbody/tr[3]/td[2]/select/option[2]').cliack()
    
    stu_name = driver.find_element_by_xpath(name).get_attribute('value')
    
    if stu_name == '':
        driver.find_element_by_xpath(registration_no).clear()
        continue
    
    if sem_gpa == '':
        i += 0
        
    else:
        i += float(driver.find_element_by_xpath(sgpa).get_attribute('value'))
        
    
    for sem in semester:
        driver.find_element_by_xpath(sem).click()
        driver.find_element_by_xpath(get_result).click()
        
        #i += float(driver.find_element_by_xpath(sgpa).get_attribute('value'))
        
        sem_gpa = driver.find_element_by_xpath(sgpa).get_attribute('value')
        
        if sem_gpa == '':
            
            i += 0
        
        else:
            
            i += float(driver.find_element_by_xpath(sgpa).get_attribute('value'))
        
    i = i/8
    
    print(student + '\t' + stu_name + '\t' + str(i))
    driver.find_element_by_xpath(registration_no).clear()
# Out:
# CSE-15-01	AZAM IFTIKHAR                                                                                       	7.278749999999999
# CSE-15-02	OWAIS NAZIR                                                                                         	8.115
# CSE-15-03	OWAIS AHMAD GANIE                                                                                   	8.731250000000001
# CSE-15-04	WASEEM UL HASSAN MIR                                                                                	7.665
# CSE-15-05	UZAIR QAYOOM                                                                                        	7.17125
# CSE-15-06	FAHEEM NABI                                                                                         	7.2975
# CSE-15-08	AQSA BILAL                                                                                          	8.5625
# CSE-15-10	MOHD UZAIR PANDIT                                                                                   	6.822499999999999
# ...

# %%
driver.find_element_by_xpath(registration_no).send_keys('CSE-15-118')
driver.find_element_by_xpath(semester).click()
driver.find_element_by_xpath(get_result).click()
